# %% [markdown]
# <a href="https://colab.research.google.com/github/raj-vijay/mv/blob/master/10_Image_Processing_Experiments_Edge_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Edge Detection**

# %% [markdown]
# Edge detection includes a variety of mathematical methods that aim at identifying points in a digital image at which the image brightness changes sharply or, more formally, has discontinuities. The points at which image brightness changes sharply are typically organized into a set of curved line segments termed edges.

# %% [markdown]
# Edge detection is a fundamental tool in image processing, machine vision and computer vision, particularly in the areas of feature detection and feature extraction.

# %%
import matplotlib.pyplot as plt
import numpy as np
def show_image(image, title='Image', cmap_type='gray'):
  plt.imshow(image, cmap=cmap_type)
  plt.title(title)
  plt.axis('on')
  plt.show()

# %%
def plot_comparison(original, filtered, title_filtered):
  fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(8, 6), sharex=True,
  sharey=True)
  ax1.imshow(original, cmap=plt.cm.gray)
  ax1.set_title('Original')
  ax1.axis('off')
  ax2.imshow(filtered, cmap=plt.cm.gray)
  ax2.set_title(title_filtered)
  ax2.axis('off')

# %% [markdown]
# **Edge detection for coins image**

# %%
from skimage import color, data

coins = data.coins()

# Convert image to grayscale
coins = color.rgb2gray(coins)

# %% [markdown]
# **a) Sobel**

# %%
# Import module and function
from skimage.filters import sobel
# Apply edge detection filter
edge_sobel = sobel(coins)
# Show original and resulting image to compare
plot_comparison(coins, edge_sobel, "Edge with Sobel")

# %% [markdown]
# **b) Canny Edge Detection**

# %%
# Apply Canny detector
from skimage.feature import canny
canny_edges = canny(coins)

# Show resulted image with edges
show_image(coins, "Original Image")
show_image(canny_edges, "Edges with Canny")

# %% [markdown]
# **c) Edge detection with Sigma**

# %%
# Apply Canny detector with a sigma of 0.5
canny_edges_0_5 = canny(coins, sigma=0.5)

# %%
# Show resulted images with edges
show_image(canny_edges, "Sigma of 1")
show_image(canny_edges_0_5, "Sigma of 0.5")

# %% [markdown]
# **Edge detection with Canny**

# %%
# Load Images
# !wget https://assets.datacamp.com/production/repositories/4470/datasets/c043d452dc01e6b6ce647e5f31afb20283879f22/toronjas.jpg
# Out:
# --2020-03-11 21:40:42--  https://assets.datacamp.com/production/repositories/4470/datasets/c043d452dc01e6b6ce647e5f31afb20283879f22/toronjas.jpg
# Resolving assets.datacamp.com (assets.datacamp.com)... 13.224.13.44, 13.224.13.62, 13.224.13.88, ...
# Connecting to assets.datacamp.com (assets.datacamp.com)|13.224.13.44|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 169770 (166K) [image/jpeg]
# Saving to: ‘toronjas.jpg’
#
# toronjas.jpg        100%[===================>] 165.79K   853KB/s    in 0.2s
#
# 2020-03-11 21:40:42 (853 KB/s) - ‘toronjas.jpg’ saved [169770/169770]

# %%
grapefruit = plt.imread('toronjas.jpg')
show_image(grapefruit, 'Original Image')

# %%
# Import the canny edge detector 
from skimage.feature import canny

# Convert image to grayscale
grapefruit = color.rgb2gray(grapefruit)

# Apply canny edge detector
canny_edges = canny(grapefruit)

# Show resulting image
show_image(canny_edges, "Edges with Canny")

# %% [markdown]
# **Comparing results with different values of sigma with Canny Edges**

# %%
# Apply canny edge detector with a sigma of 1.8
edges_1_8 = canny(grapefruit, sigma=1.8)

# Apply canny edge detector with a sigma of 2.2
edges_2_2 = canny(grapefruit, sigma=2.2)

# Show resulting images
show_image(edges_1_8, "Sigma of 1.8")
show_image(edges_2_2, "Sigma of 2.2")

# %% [markdown]
# *Personal notes on Image Processing with Python from Datacamp
